# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
# Define your connection parameters
connection_params = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'root',
    'host': 'localhost',  # or the IP address of your PostgreSQL server
    'port': '5432'        # default PostgreSQL port
}

# Establish a connection to the database
try:
    conn = psycopg2.connect(**connection_params)
    print("Connection successful!")
except Exception as e:
    print(f"Error connecting to the database: {e}")
# Out:
# Connection successful!

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public';")
tables = cursor.fetchall()

# %%
print("Tables in the database:")
for table in tables:
    print(table[0])
# Out:
# Tables in the database:
# resetTokens
# users
# cart
# cart_item
# orders
# order_item
# reviews
# products

# %%
table_name = 'products'  # Replace with your table name

# Read the table into a DataFrame
df = pd.read_sql(f"SELECT * FROM {table_name};", conn)

# Display the DataFrame
(df.head())
# Out:
# C:\Users\Umesh\AppData\Local\Temp\ipykernel_4728\2739915317.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM {table_name};", conn)
#    product_id                                               name  \
# 0       10034    Madagascar3 Girls Purple Printed T-Shirt(10034)
# 1       10035  Disney Kids Boys Crew Sea Life Sialing Green T...
# 2       10036  Doodle Boys Route 66 Biker Blue Teen Kidswear(...
# 3       10037             Palm Tree Boys Check Blue Shirt(10037)
# 4       10038        Gini and Jony Boys Solid Black Jeans(10038)
#
#               slug   price                                        description  \
# 0     Topwear10034  3144.0           Madagascar3 Girls Purple Printed T-Shirt
# 1     Topwear10035  1846.0  Disney Kids Boys Crew Sea Life Sialing Green T...
# 2     Topwear10036  3795.0      Doodle Boys Route 66 Biker Blue Teen Kidswear
# 3     Topwear10037  1282.0                    Palm Tree Boys Check Blue Shirt
# 4  Bottomwear10038   676.0               Gini and Jony Boys Solid Black Jeans
#
#                                            image_url  discount_max  \
# 0  http://assets.myntassets.com/v1/images/style/p...          47.0
# 1  http://assets.myntassets.com/v1/images/style/p...          65.0
# 2  http://assets.myntassets.com/v1/images/style/p...          52.0
# 3  http://assets.myntassets.com/v1/images/style/p...          38.0
# 4  http://assets.myntassets.com/v1/images/style/p...          43.0
#
#    discount_price  rating  margin    category gender
# 0         2766.72       3      40     Topwear  Girls
# 1         1606.02       4      40     Topwear   Boys
# 2         3187.80       2      40     Topwear   Boys
# 3         1102.52       3      40     Topwear   Boys
# 4          547.56       2      40  Bottomwear   Boys

# %%
connection_string = f"postgresql+psycopg2://{connection_params['user']}:{connection_params['password']}@{connection_params['host']}:{connection_params['port']}/{connection_params['dbname']}"
engine = create_engine(connection_string)

# %%
import psycopg2

# Define your connection parameters
connection_params = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'root',
    'host': 'localhost',  # or the IP address of your PostgreSQL server
    'port': '5432'        # default PostgreSQL port
}

# Establish a connection
conn = None
cursor = None
try:
    conn = psycopg2.connect(**connection_params)
    cursor = conn.cursor()

    # Step 1: Fetch rows from the table
    table_name = 'products'  # Replace with your table name
    cursor.execute(f"SELECT product_id, name, slug, price, description, image_url, discount_max, discount_price, rating, margin, category, gender FROM {table_name};")  # Replace column1, column2 as needed
    rows = cursor.fetchall()

    # Step 2: Process each row
    for row in rows:
        product_id = row[0]  
        discount_max = row[6]
        discount_price = row[7]
        rating = row[8]
        margin = row[9]
        category = row[10]
        gender = row[11]
        
        
        #print(row)
        # Perform the operation to compute discount_max and discount_price
        # 
        computed_value = len(name)  # Example operation: Get the length of the name

        # Step 3: Update the row with the computed value
        cursor.execute(f"UPDATE {table_name} SET discount_max = %s WHERE product_id = %s;", (computed_value, product_id))

    # Commit the transaction
    conn.commit()

except Exception as e:
    print(f"Error: {e}")
    if conn:
        conn.rollback()  # Rollback in case of error

finally:
    # Close the cursor and connection
    if cursor:
        cursor.close()
    if conn:
        conn.close()

# %%
# Out:
# hrllo
